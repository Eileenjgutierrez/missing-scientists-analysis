# %% [markdown]
# <a href="https://colab.research.google.com/github/Eileenjgutierrez/missing-scientists-analysis/blob/main/01_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Data Science")
# Out:
# Hello Data Science

# %%
# !pip install pandas numpy matplotlib seaborn nltk scikit-learn beautifulsoup4 requests wordcloud textblob
